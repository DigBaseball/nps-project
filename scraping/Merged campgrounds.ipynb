# %%
import pandas as pd

# %%
comdined_Data= pd.read_csv("combine.csv")

# %%
final_data=comdined_Data.groupby(['name','Qtr']).mean()

# %%
final_data
# Out:
#                                                       maxtempC   mintempC  \
# name                                            Qtr
# Abrams Creek Campground                         1.0  10.214588   0.768232
#                                                 2.0  23.231990  11.133089
#                                                 3.0  27.251208  15.128019
#                                                 4.0  14.166667   4.163043
# Adirondack Shelters Rental Information          1.0   5.680456  -2.726044
#                                                 2.0  21.489621  10.405372
#                                                 3.0  26.723430  15.841787
#                                                 4.0  11.077295   2.640097
# Afterbay Campground                             1.0   2.135983  -5.941140
#                                                 2.0  16.709402   5.868132
#                                                 3.0  25.753623  13.898551
# ...

# %%
final_data=final_data.reset_index()

# %%
final_data
# Out:
#                                                  name  Qtr   maxtempC  \
# 0                             Abrams Creek Campground  1.0  10.214588
# 1                             Abrams Creek Campground  2.0  23.231990
# 2                             Abrams Creek Campground  3.0  27.251208
# 3                             Abrams Creek Campground  4.0  14.166667
# 4              Adirondack Shelters Rental Information  1.0   5.680456
# 5              Adirondack Shelters Rental Information  2.0  21.489621
# 6              Adirondack Shelters Rental Information  3.0  26.723430
# 7              Adirondack Shelters Rental Information  4.0  11.077295
# 8                                 Afterbay Campground  1.0   2.135983
# 9                                 Afterbay Campground  2.0  16.709402
# 10                                Afterbay Campground  3.0  25.753623
# 11                                Afterbay Campground  4.0   5.519324
# ...

# %%
final_data.to_csv(r'C:\Users\User\Desktop\dani\Combine_final_dataset.csv', index = False)
