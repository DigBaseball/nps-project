# %%
import pandas as pd

# %%
data1= pd.read_csv("campgrounds.csv")

# %%
data2= pd.read_csv("Combine_final_dataset.csv")

# %%
data=data1[["parkCode","name"]]

# %%
data
# Out:
#     parkCode                                               name
# 0       apis          Presque Isle Campground - Stockton Island
# 1       arch                           Devils Garden Campground
# 2       asis                         Oceanside Group Campground
# 3       asis            Ocean side drive in campground - Loop 1
# 4       asis            Ocean side drive in campground - Loop 2
# 5       asis              Bay side drive in campground - Loop A
# 6       asis  Bay side drive in campground - Loop B (no gene...
# 7       asis              Bay side drive in campground - Loop C
# 8       asis                     Walk in campground - Walk in 1
# 9       asis                     Walk in campground - Walk in 2
# 10      asis                     Walk in campground - Walk in 3
# 11      asis                                      Horse camping
# 12      asis              Back Country Camping - Tingles Island
# 13      asis                   Back Country Camping - Pine Tree
# ...

# %%
data2
# Out:
#                                                  name  Qtr   maxtempC  \
# 0                             Abrams Creek Campground  1.0  10.214588
# 1                             Abrams Creek Campground  2.0  23.231990
# 2                             Abrams Creek Campground  3.0  27.251208
# 3                             Abrams Creek Campground  4.0  14.166667
# 4              Adirondack Shelters Rental Information  1.0   5.680456
# 5              Adirondack Shelters Rental Information  2.0  21.489621
# 6              Adirondack Shelters Rental Information  3.0  26.723430
# 7              Adirondack Shelters Rental Information  4.0  11.077295
# 8                                 Afterbay Campground  1.0   2.135983
# 9                                 Afterbay Campground  2.0  16.709402
# 10                                Afterbay Campground  3.0  25.753623
# 11                                Afterbay Campground  4.0   5.519324
# ...

# %%
df3 = pd.merge(data2, data)

# %%
df3
# Out:
#                                                  name  Qtr   maxtempC  \
# 0                             Abrams Creek Campground  1.0  10.214588
# 1                             Abrams Creek Campground  2.0  23.231990
# 2                             Abrams Creek Campground  3.0  27.251208
# 3                             Abrams Creek Campground  4.0  14.166667
# 4              Adirondack Shelters Rental Information  1.0   5.680456
# 5              Adirondack Shelters Rental Information  2.0  21.489621
# 6              Adirondack Shelters Rental Information  3.0  26.723430
# 7              Adirondack Shelters Rental Information  4.0  11.077295
# 8                                 Afterbay Campground  1.0   2.135983
# 9                                 Afterbay Campground  2.0  16.709402
# 10                                Afterbay Campground  3.0  25.753623
# 11                                Afterbay Campground  4.0   5.519324
# ...

# %%
df3.to_csv(r'C:\Users\User\Desktop\dani\with_park_code.csv', index = False)
